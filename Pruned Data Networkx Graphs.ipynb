# %%
import functions as f
import networkx as nx
import matplotlib.pyplot as plt2
from networkx.algorithms import community
from networkx import edge_betweenness_centrality as betweenness
import numpy as np
dic = f.open_file2("./Data/hsv1_final_data.txt")

# %%
hr0_top = f.draw_network(dic, [0])

# %%
hr0_com0 = f.draw_community(hr0_top, 0)

# %%
hr1_top = f.draw_network(dic, [1])

# %%
hr3_top = f.draw_network(dic, [2])

# %%
hr8_top = f.draw_network(dic, [3])

# %%
hr15_top = f.draw_network(dic, [4])
