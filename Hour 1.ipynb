# %%
import functions as f
import networkx as nx
import matplotlib.pyplot as plt2
from networkx.algorithms import community
from networkx import edge_betweenness_centrality as betweenness
import numpy as np
x = f.open_file2("./Data/hsv1_final_data.txt")

# %%
hr1_net = f.draw_network(x, [1,2])

# %%
hr1_0 = f.draw_community(hr1_net, 0)

# %%
hr1_0_0 = f.draw_community(hr1_0, 0)

# %%
hr1_0_1 = f.draw_community(hr1_0, 1)

# %%
hr1_1 = f.draw_community(hr1_net, 1)

# %%
nodes = f.format_nodes(hr1_net.nodes())
# Out:
# ABCE1
# CYCS
# EIF3J
# PSMA4
# UQCRB
# ACADM
# HSPD1
# ACOT13
# ATP5J
# CDC26
# COA6
# NDUFV2
# ACTN1
# RDX
# ACTN4
# ADAR
# EIF2AK2
# ADIRF
# TMSB4X
# AHCY
# TSTA3
# AIFM1
# GLUD1
# MDH2
# NDUFV1
# AIMP2
# AIMP1
# ALCAM
# NDUFA5
# NUCKS1
# PDIA5
# RRP9
# TCEAL3
# ALYREF
# SRSF3
# ANAPC13
# ANXA1
# ANXA4
# ANXA5
# ANXA11
# ANXA2
# EZR
# APOA1
# MANF
# PQBP1
# SOD2
# ARF3
# CTSL
# ARHGAP12
# ABI1
# ARL6IP1
# RPS3A
# ARMC9
# CSDE1
# ARPP19
# CNBP
# ENSA
# PTMA
# ATP5A1
# ACOX1
# ATP5B
# ATP5C1
# ATP5D
# ATP5E
# BSG
# DBI
# DLD
# ECI1
# ERH
# FIP1L1
# GOT2
# KIAA0101
# MGARP
# MT2A
# NDUFA7
# NDUFS6
# NDUFV3
# NIPSNAP3A
# SLC3A2
# TMSB10
# COX6B1
# ACAA2
# CETN2
# CHCHD4
# COX5A
# GAPDH
# HMGN2
# HSPE1
# KRT1
# KRT9
# LAMTOR3
# PDAP1
# PPP1R14A
# SARNP
# SNRPC
# SOD1
# SSR3
# COA4
# L0R819
# RPLP2
# RPS28
# COX5B
# FAM107B
# PDCD5
# PSMA7
# SSBP1
# TXN
# B2M
# OCIAD1
# PRAF2
# UQCRFS1
# ATPIF1
# BAG3
# GOT1
# BASP1
# CALD1
# CAST
# KIAA1143
# MARCKS
# MARCKSL1
# PTMS
# PVR
# RCN1
# ...
